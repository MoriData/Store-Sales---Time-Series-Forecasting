# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/store-sales-time-series-forecasting/oil.csv
# /kaggle/input/store-sales-time-series-forecasting/sample_submission.csv
# /kaggle/input/store-sales-time-series-forecasting/holidays_events.csv
# /kaggle/input/store-sales-time-series-forecasting/stores.csv
# /kaggle/input/store-sales-time-series-forecasting/train.csv
# /kaggle/input/store-sales-time-series-forecasting/test.csv
# /kaggle/input/store-sales-time-series-forecasting/transactions.csv

# %% [markdown]
# # Liberies

# %%
# Standard Libraries
import numpy as np
import pandas as pd

# Machine Learning Models and Metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Time Series Libraries
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Machine Learning Frameworks
import xgboost as xgb
from catboost import CatBoostRegressor, Pool
from lightgbm import LGBMRegressor


# For Suppressing Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Data

# %%
# Load the training and test datasets
train = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/train.csv')
test = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/test.csv')

# %%
# add the 'dataset' column to distinguish train and test data
train['dataset'] = 'train'
test['dataset'] = 'test'

# concatenate the datasets with the added 'dataset' column
df = pd.concat([train, test], axis=0).reset_index(drop=True)

# %%
oil_data = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/oil.csv')
holidays_data = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/holidays_events.csv')
store_data = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/stores.csv')
transactions_data = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/transactions.csv')

# %%
print(df.columns)
print(oil_data.columns)
print(holidays_data.columns)
print(store_data.columns)
print(transactions_data.columns)
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion', 'dataset'], dtype='object')
# Index(['date', 'dcoilwtico'], dtype='object')
# Index(['date', 'type', 'locale', 'locale_name', 'description', 'transferred'], dtype='object')
# Index(['store_nbr', 'city', 'state', 'type', 'cluster'], dtype='object')
# Index(['date', 'store_nbr', 'transactions'], dtype='object')

# %%
train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion dataset
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0   train
# 1   1  2013-01-01          1   BABY CARE    0.0            0   train
# 2   2  2013-01-01          1      BEAUTY    0.0            0   train
# 3   3  2013-01-01          1   BEVERAGES    0.0            0   train
# 4   4  2013-01-01          1       BOOKS    0.0            0   train

# %%
test
# Out:
#             id        date  store_nbr                      family  \
# 0      3000888  2017-08-16          1                  AUTOMOTIVE
# 1      3000889  2017-08-16          1                   BABY CARE
# 2      3000890  2017-08-16          1                      BEAUTY
# 3      3000891  2017-08-16          1                   BEVERAGES
# 4      3000892  2017-08-16          1                       BOOKS
# ...        ...         ...        ...                         ...
# 28507  3029395  2017-08-31          9                     POULTRY
# 28508  3029396  2017-08-31          9              PREPARED FOODS
# 28509  3029397  2017-08-31          9                     PRODUCE
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES
# 28511  3029399  2017-08-31          9                     SEAFOOD
#
#        onpromotion dataset
# 0                0    test
# 1                0    test
# 2                2    test
# 3               20    test
# 4                0    test
# ...            ...     ...
# 28507            1    test
# 28508            0    test
# 28509            1    test
# 28510            9    test
# 28511            0    test
#
# [28512 rows x 6 columns]

# %%
oil_data
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
holidays_data
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# 345                      Navidad-3        False
# 346                      Navidad-2        False
# 347                      Navidad-1        False
# 348                        Navidad        False
# 349                      Navidad+1        False
#
# [350 rows x 6 columns]

# %%
holidays_data[holidays_data['transferred'] == True]
# Out:
#            date     type    locale locale_name                    description  \
# 19   2012-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 72   2013-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 135  2014-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 255  2016-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 266  2016-07-25  Holiday     Local   Guayaquil         Fundacion de Guayaquil
# 268  2016-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 297  2017-01-01  Holiday  National     Ecuador             Primer dia del ano
# 303  2017-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 312  2017-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 324  2017-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 328  2017-09-28  Holiday     Local      Ibarra            Fundacion de Ibarra
# 340  2017-12-06  Holiday     Local       Quito             Fundacion de Quito
#
#      transferred
# 19          True
# 72          True
# 135         True
# 255         True
# 266         True
# 268         True
# 297         True
# 303         True
# 312         True
# 324         True
# 328         True
# 340         True

# %%
holidays_data[holidays_data['type'] == 'Transfer']
# Out:
#            date      type    locale locale_name  \
# 20   2012-10-12  Transfer  National     Ecuador
# 73   2013-10-11  Transfer  National     Ecuador
# 136  2014-10-10  Transfer  National     Ecuador
# 256  2016-05-27  Transfer  National     Ecuador
# 265  2016-07-24  Transfer     Local   Guayaquil
# 269  2016-08-12  Transfer  National     Ecuador
# 298  2017-01-02  Transfer  National     Ecuador
# 304  2017-04-13  Transfer     Local      Cuenca
# 313  2017-05-26  Transfer  National     Ecuador
# 325  2017-08-11  Transfer  National     Ecuador
# 329  2017-09-29  Transfer     Local      Ibarra
# 342  2017-12-08  Transfer     Local       Quito
#
#                                 description  transferred
# 20      Traslado Independencia de Guayaquil        False
# 73      Traslado Independencia de Guayaquil        False
# 136     Traslado Independencia de Guayaquil        False
# 256           Traslado Batalla de Pichincha        False
# 265         Traslado Fundacion de Guayaquil        False
# 269  Traslado Primer Grito de Independencia        False
# 298             Traslado Primer dia del ano        False
# 304                     Fundacion de Cuenca        False
# 313           Traslado Batalla de Pichincha        False
# 325  Traslado Primer Grito de Independencia        False
# 329                     Fundacion de Ibarra        False
# 342             Traslado Fundacion de Quito        False

# %%
holidays_data[holidays_data['type'] == 'Bridge']
# Out:
#            date    type    locale locale_name                description  \
# 35   2012-12-24  Bridge  National     Ecuador             Puente Navidad
# 39   2012-12-31  Bridge  National     Ecuador  Puente Primer dia del ano
# 156  2014-12-26  Bridge  National     Ecuador             Puente Navidad
# 160  2015-01-02  Bridge  National     Ecuador  Puente Primer dia del ano
# 277  2016-11-04  Bridge  National     Ecuador     Puente Dia de Difuntos
#
#      transferred
# 35         False
# 39         False
# 156        False
# 160        False
# 277        False

# %%
holidays_data[holidays_data['type'] == 'Transfer']
# Out:
#            date      type    locale locale_name  \
# 20   2012-10-12  Transfer  National     Ecuador
# 73   2013-10-11  Transfer  National     Ecuador
# 136  2014-10-10  Transfer  National     Ecuador
# 256  2016-05-27  Transfer  National     Ecuador
# 265  2016-07-24  Transfer     Local   Guayaquil
# 269  2016-08-12  Transfer  National     Ecuador
# 298  2017-01-02  Transfer  National     Ecuador
# 304  2017-04-13  Transfer     Local      Cuenca
# 313  2017-05-26  Transfer  National     Ecuador
# 325  2017-08-11  Transfer  National     Ecuador
# 329  2017-09-29  Transfer     Local      Ibarra
# 342  2017-12-08  Transfer     Local       Quito
#
#                                 description  transferred
# 20      Traslado Independencia de Guayaquil        False
# 73      Traslado Independencia de Guayaquil        False
# 136     Traslado Independencia de Guayaquil        False
# 256           Traslado Batalla de Pichincha        False
# 265         Traslado Fundacion de Guayaquil        False
# 269  Traslado Primer Grito de Independencia        False
# 298             Traslado Primer dia del ano        False
# 304                     Fundacion de Cuenca        False
# 313           Traslado Batalla de Pichincha        False
# 325  Traslado Primer Grito de Independencia        False
# 329                     Fundacion de Ibarra        False
# 342             Traslado Fundacion de Quito        False

# %%
holidays_data.loc[holidays_data['type'] == 'Transfer', 'type'] = 'Holiday'

# %%
holidays_data['Holiday summary'] = (
    holidays_data['type'].astype(str) + " " +
    holidays_data['locale'].astype(str) + " " +
    holidays_data['locale_name'].astype(str) + " " 
    # holidays_data['description'].astype(str)
)

# %%
holidays_data= holidays_data.drop(columns=['type', 'locale', 'locale_name', 'description'] , errors='ignore' )

# %%
holidays_data['Holiday summary'].value_counts()
# Out:
# Holiday summary
# Holiday National Ecuador                            68
# Event National Ecuador                              56
# Additional National Ecuador                         40
# Holiday Local Latacunga                             12
# Holiday Local Riobamba                              12
# Holiday Local Guaranda                              12
# Holiday Local Ambato                                12
# Holiday Local Cuenca                                 7
# Holiday Local Quito                                  7
# Holiday Local Ibarra                                 7
# Holiday Local Puyo                                   6
# Holiday Local Libertad                               6
# Holiday Regional Cotopaxi                            6
# Holiday Local Manta                                  6
# Holiday Local Esmeraldas                             6
# Holiday Local Cayambe                                6
# Holiday Local El Carmen                              6
# Holiday Local Santo Domingo                          6
# Holiday Local Machala                                6
# Holiday Regional Imbabura                            6
# Holiday Local Quevedo                                6
# Holiday Regional Santo Domingo de los Tsachilas      6
# Additional Local Quito                               6
# Holiday Regional Santa Elena                         6
# Holiday Local Salinas                                6
# Holiday Local Loja                                   6
# Holiday Local Guayaquil                              6
# Bridge National Ecuador                              5
# Work Day National Ecuador                            5
# Additional Local Guayaquil                           5
# Name: count, dtype: int64

# %%
store_data
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# 11         12      Latacunga                        Cotopaxi    C       15
# 12         13      Latacunga                        Cotopaxi    C       15
# 13         14       Riobamba                      Chimborazo    C        7
# 14         15         Ibarra                        Imbabura    C       15
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 16         17          Quito                       Pichincha    C       12
# 17         18          Quito                       Pichincha    B       16
# 18         19       Guaranda                         Bolivar    C       15
# 19         20          Quito                       Pichincha    B        6
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas    B        6
# 21         22           Puyo                         Pastaza    C        7
# 22         23         Ambato                      Tungurahua    D        9
# 23         24      Guayaquil                          Guayas    D        1
# 24         25        Salinas                     Santa Elena    D        1
# 25         26      Guayaquil                          Guayas    D       10
# 26         27          Daule                          Guayas    D        1
# 27         28      Guayaquil                          Guayas    E       10
# 28         29      Guayaquil                          Guayas    E       10
# 29         30      Guayaquil                          Guayas    C        3
# 30         31       Babahoyo                        Los Rios    B       10
# 31         32      Guayaquil                          Guayas    C        3
# 32         33        Quevedo                        Los Rios    C        3
# 33         34      Guayaquil                          Guayas    B        6
# 34         35         Playas                          Guayas    C        3
# 35         36       Libertad                          Guayas    E       10
# 36         37         Cuenca                           Azuay    D        2
# 37         38           Loja                            Loja    D        4
# 38         39         Cuenca                           Azuay    B        6
# 39         40        Machala                          El Oro    C        3
# 40         41        Machala                          El Oro    D        4
# 41         42         Cuenca                           Azuay    D        2
# 42         43     Esmeraldas                      Esmeraldas    E       10
# 43         44          Quito                       Pichincha    A        5
# 44         45          Quito                       Pichincha    A       11
# 45         46          Quito                       Pichincha    A       14
# 46         47          Quito                       Pichincha    A       14
# 47         48          Quito                       Pichincha    A       14
# 48         49          Quito                       Pichincha    A       11
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
# 53         54      El Carmen                          Manabi    C        3

# %%
transactions_data
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
store_data['state'].value_counts()
# Out:
# state
# Pichincha                         19
# Guayas                            11
# Azuay                              3
# Santo Domingo de los Tsachilas     3
# Manabi                             3
# Los Rios                           2
# Cotopaxi                           2
# Tungurahua                         2
# El Oro                             2
# Bolivar                            1
# Imbabura                           1
# Chimborazo                         1
# Pastaza                            1
# Santa Elena                        1
# Loja                               1
# Esmeraldas                         1
# Name: count, dtype: int64

# %%
store_data['city'].value_counts()
# Out:
# city
# Quito            18
# Guayaquil         8
# Cuenca            3
# Santo Domingo     3
# Latacunga         2
# Machala           2
# Manta             2
# Ambato            2
# Cayambe           1
# Riobamba          1
# Ibarra            1
# Salinas           1
# Puyo              1
# Guaranda          1
# Quevedo           1
# Babahoyo          1
# Daule             1
# Playas            1
# Loja              1
# Libertad          1
# Esmeraldas        1
# El Carmen         1
# Name: count, dtype: int64

# %%
# Merge oil prices data on date
df = df.merge(oil_data, on='date', how='left')

# %%
# Merge holiday data on date
df = df.merge(holidays_data, on='date', how='left')

# %%
# Merge store data on store number
df = df.merge(store_data, on='store_nbr', how='left')

# %%
# Merge transaction data on store number and date
df = df.merge(transactions_data, on=['date', 'store_nbr'], how='left')

# %%
df.sample(30)
# Out:
#               id        date  store_nbr               family     sales  \
# 2796542  2750210  2017-03-28         25            MAGAZINES     7.000
# 666729    657819  2014-01-06         16              PRODUCE   719.106
# 2828658  2781123  2017-04-14         42   HOME AND KITCHEN I    11.000
# 278273    276491  2013-06-05         17      HOME APPLIANCES     0.000
# 1452787  1433185  2015-03-18         21              POULTRY     0.000
# 550029    542901  2013-11-01         41            HOME CARE     0.000
# 2607463  2562913  2016-12-12         20            BABY CARE     3.000
# 1310563  1290961  2014-12-28         31            BABY CARE     0.000
# 1141541  1125503  2014-09-25         39         BREAD/BAKERY   525.000
# 1286874  1270836  2014-12-16         17          CELEBRATION     4.000
# 185427    185427  2013-04-15         12           AUTOMOTIVE     1.000
# 187278    187278  2013-04-16         14            BEVERAGES   311.000
# 1796687  1771739  2015-09-24         21               BEAUTY     6.000
# 1321443  1301841  2015-01-03         36                MEATS   330.695
# 2018131  1991401  2016-01-26         34  HOME AND KITCHEN II    21.000
# 1788900  1763952  2015-09-19         52            BEVERAGES     0.000
# 370713    363585  2013-07-24         10                MEATS   185.565
# 1644477  1621311  2015-07-01          5             LINGERIE    32.000
# 1502169  1482567  2015-04-14          8                 DELI   222.393
# 511850    504722  2013-10-11         20      LAWN AND GARDEN     0.000
# 1559106  1539504  2015-05-16         54             LINGERIE     0.000
# 1561600  1541998  2015-05-18         25             CLEANING   279.000
# 1472430  1452828  2015-03-29         23            BEVERAGES   822.000
# 2371760  2328992  2016-08-02          7      HOME APPLIANCES     0.000
# 1233069  1217031  2014-11-15          7                MEATS   477.098
# 1553813  1534211  2015-05-13          7                DAIRY  1369.000
# 2053275  2026545  2016-02-15         20   HOME AND KITCHEN I    20.000
# 2975123  2922962  2017-07-03         22      LAWN AND GARDEN     0.000
# 2713009  2666677  2017-02-09         31           GROCERY II     5.000
# 2447696  2404928  2016-09-14         37      LAWN AND GARDEN    17.000
#
#          onpromotion dataset  dcoilwtico transferred  \
# 2796542            0   train       48.36         NaN
# 666729             0   train       93.12         NaN
# 2828658            1   train         NaN       False
# 278273             0   train       93.66         NaN
# 1452787            0   train       44.63         NaN
# 550029             0   train       94.56         NaN
# 2607463            0   train       52.74         NaN
# 1310563            0   train         NaN         NaN
# 1141541            1   train       93.59         NaN
# 1286874            0   train       55.97         NaN
# 185427             0   train       88.75         NaN
# 187278             0   train       88.73         NaN
# 1796687            0   train       44.94         NaN
# 1321443            4   train         NaN         NaN
# 2018131            0   train       29.54         NaN
# 1788900            0   train         NaN         NaN
# 370713             0   train      105.41       False
# 1644477            0   train       56.94         NaN
# 1502169            1   train       53.30       False
# 511850             0   train      102.17       False
# 1559106            0   train         NaN         NaN
# 1561600            2   train       59.44         NaN
# 1472430            0   train         NaN         NaN
# 2371760            0   train       39.50         NaN
# 1233069           10   train         NaN         NaN
# 1553813            1   train       60.50         NaN
# 2053275            0   train         NaN         NaN
# 2975123            0   train         NaN       False
# 2713009            0   train       52.99         NaN
# 2447696            2   train       43.62         NaN
#
#                       Holiday summary           city  \
# 2796542                           NaN        Salinas
# 666729                            NaN  Santo Domingo
# 2828658       Holiday Local Libertad          Cuenca
# 278273                            NaN          Quito
# 1452787                           NaN  Santo Domingo
# 550029                            NaN        Machala
# 2607463                           NaN          Quito
# 1310563                           NaN       Babahoyo
# 1141541                           NaN         Cuenca
# 1286874                           NaN          Quito
# 185427                            NaN      Latacunga
# 187278                            NaN       Riobamba
# 1796687                           NaN  Santo Domingo
# 1321443                           NaN       Libertad
# 2018131                           NaN      Guayaquil
# 1788900                           NaN          Manta
# 370713    Additional Local Guayaquil           Quito
# 1644477                           NaN  Santo Domingo
# 1502169       Holiday Local Libertad           Quito
# 511850      Holiday National Ecuador           Quito
# 1559106                           NaN      El Carmen
# 1561600                           NaN        Salinas
# 1472430                           NaN         Ambato
# 2371760                           NaN          Quito
# 1233069                           NaN          Quito
# 1553813                           NaN          Quito
# 2053275                           NaN          Quito
# 2975123  Holiday Local Santo Domingo            Puyo
# 2713009                           NaN       Babahoyo
# 2447696                           NaN         Cuenca
#
#                                   state type  cluster  transactions
# 2796542                     Santa Elena    D        1         836.0
# 666729   Santo Domingo de los Tsachilas    C        3         897.0
# 2828658                           Azuay    D        2        1104.0
# 278273                        Pichincha    C       12        1251.0
# 1452787  Santo Domingo de los Tsachilas    B        6           NaN
# 550029                           El Oro    D        4         930.0
# 2607463                       Pichincha    B        6        1333.0
# 1310563                        Los Rios    B       10        1707.0
# 1141541                           Azuay    B        6        1190.0
# 1286874                       Pichincha    C       12        1499.0
# 185427                         Cotopaxi    C       15        1296.0
# 187278                       Chimborazo    C        7        1497.0
# 1796687  Santo Domingo de los Tsachilas    B        6         962.0
# 1321443                          Guayas    E       10        1488.0
# 2018131                          Guayas    B        6        1962.0
# 1788900                          Manabi    A       11           NaN
# 370713                        Pichincha    C       15         932.0
# 1644477  Santo Domingo de los Tsachilas    D        4        1517.0
# 1502169                       Pichincha    D        8        2333.0
# 511850                        Pichincha    B        6           NaN
# 1559106                          Manabi    C        3         969.0
# 1561600                     Santa Elena    D        1         639.0
# 1472430                      Tungurahua    D        9         974.0
# 2371760                       Pichincha    D        8        1727.0
# 1233069                       Pichincha    D        8        1828.0
# 1553813                       Pichincha    D        8        1755.0
# 2053275                       Pichincha    B        6        1368.0
# 2975123                         Pastaza    C        7         859.0
# 2713009                        Los Rios    B       10        1216.0
# 2447696                           Azuay    D        2        1325.0

# %% [markdown]
# ## 1.1: Basic Data Overview

# %%
# Basic info and shape
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
df.info()

# Checking for missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (3082860, 15)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3082860 entries, 0 to 3082859
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   id               int64
#  1   date             object
#  2   store_nbr        int64
#  3   family           object
#  4   sales            float64
#  5   onpromotion      int64
#  6   dataset          object
#  7   dcoilwtico       float64
#  8   transferred      object
#  9   Holiday summary  object
#  10  city             object
#  11  state            object
#  12  type             object
#  13  cluster          int64
#  14  transactions     float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 352.8+ MB
#
# Missing Values in Each Column:
# id                       0
# date                     0
# store_nbr                0
# family                   0
# sales                28512
# onpromotion              0
# dataset                  0
# dcoilwtico          962280
# transferred        2578554
# Holiday summary    2578554
# city                     0
# state                    0
# type                     0
# cluster                  0
# transactions        277629
# dtype: int64

# %%
# Summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
df.describe()
# Out:
# Summary Statistics for Numerical Columns:
#                  id     store_nbr         sales   onpromotion    dcoilwtico  \
# count  3.082860e+06  3.082860e+06  3.054348e+06  3.082860e+06  2.120580e+06
# mean   1.518250e+06  2.750000e+01  3.590209e+02  2.657692e+00  6.780640e+01
# std    8.742912e+05  1.558579e+01  1.107286e+03  1.236626e+01  2.564571e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  2.619000e+01
# 25%    7.618048e+05  1.400000e+01  0.000000e+00  0.000000e+00  4.646000e+01
# 50%    1.521828e+06  2.750000e+01  1.100000e+01  0.000000e+00  5.325000e+01
# 75%    2.272940e+06  4.100000e+01  1.960110e+02  0.000000e+00  9.572000e+01
# max    3.029399e+06  5.400000e+01  1.247170e+05  7.410000e+02  1.106200e+02
#
#             cluster  transactions
# count  3.082860e+06  2.805231e+06
# mean   8.481481e+00  1.697071e+03
# std    4.649735e+00  9.668317e+02
# min    1.000000e+00  5.000000e+00
# 25%    4.000000e+00  1.046000e+03
# 50%    8.500000e+00  1.395000e+03
# 75%    1.300000e+01  2.081000e+03
# max    1.700000e+01  8.359000e+03

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# ## 2.1: Handle Missing Values

# %%
# Handle missing values in the dataset

# Fill missing values in oil prices using forward fill, then backward fill
df['dcoilwtico'] = df['dcoilwtico'].fillna(method='ffill').fillna(method='bfill')

# Create a binary column 'is_holiday'
# Set 0 for 'Not Holiday' and 1 for any holiday-related value
df['is_holiday'] = df['Holiday summary'].fillna('Not Holiday').apply(lambda x: 0 if x == 'Not Holiday' else 1)

# Handle missing values in the 'transactions' column:
# Step 1: Fill missing transactions with the median transactions for each product family
df['transactions'] = df.groupby('family')['transactions'].transform(
    lambda x: x.fillna(x.median())
)

# Step 2: For any remaining missing values, apply forward fill
df['transactions'].fillna(method='ffill', inplace=True)

# Step 3: If forward fill fails (e.g., for the first row), fill with the overall mean
df['transactions'].fillna(df['transactions'].mean(), inplace=True)

# Drop unnecessary columns
df = df.drop(columns=['transferred', 'Holiday summary'], errors='ignore')

# %%
# Checking for missing values
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# id                  0
# date                0
# store_nbr           0
# family              0
# sales           28512
# onpromotion         0
# dataset             0
# dcoilwtico          0
# city                0
# state               0
# type                0
# cluster             0
# transactions        0
# is_holiday          0
# dtype: int64

# %% [markdown]
# ## 2.2 Convert Date Column and Extract Temporal Features

# %%
# Extract year, month, day, day of the week, and other possible temporal features
# Convert 'date' column to numerical features
df['date'] = pd.to_datetime(df['date'])
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

df = df.sort_values(by='date')

# %% [markdown]
# ## 2.3: Encode Categorical Variables

# %%
df['family'].value_counts()
df.groupby('family', as_index=False).agg(
    sales_count=('sales', 'count'),
    sales_mean=('sales', 'mean')
).sort_values(by='sales_mean', ascending=False)[:10]
# Out:
#            family  sales_count   sales_mean
# 12      GROCERY I        92556  3790.432797
# 3       BEVERAGES        92556  2394.912701
# 30        PRODUCE        92556  1355.373698
# 7        CLEANING        92556  1074.171518
# 8           DAIRY        92556   711.175991
# 5    BREAD/BAKERY        92556   464.150612
# 28        POULTRY        92556   351.078816
# 24          MEATS        92556   341.965905
# 25  PERSONAL CARE        92556   271.192381
# 9            DELI        92556   265.629746

# %%
df.groupby('store_nbr', as_index=False).agg(
    sales_count=('sales', 'count'),
    sales_mean=('sales', 'mean')
).sort_values(by='sales_mean', ascending=False)[:10]
# Out:
#     store_nbr  sales_count   sales_mean
# 43         44        56562  1120.118405
# 44         45        56562   984.565998
# 46         47        56562   919.777871
# 2           3        56562   911.098054
# 48         49        56562   784.039156
# 45         46        56562   756.775349
# 47         48        56562   649.584599
# 50         51        56562   594.106667
# 7           8        56562   550.264615
# 49         50        56562   517.551554

# %%
df.columns
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion', 'dataset',
#        'dcoilwtico', 'city', 'state', 'type', 'cluster', 'transactions',
#        'is_holiday', 'day', 'day_of_week', 'month', 'year'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder


# One-Hot Encoding for selected columns
# Perform one-hot encoding on 'store_type' and 'family' columns
df = pd.get_dummies(df, columns=['store_nbr', 'family'], dtype=int, drop_first=True)

# Function for Target Encoding multiple categorical columns
def target_encoding_multiple_columns(df, target_column, categorical_columns, dataset_column='dataset'):
    
    for col in categorical_columns:
        # Calculate target mean for each category in the column using training data
        target_mean = df[df[dataset_column] == 'train'].groupby(col)[target_column].mean()

        # Map the target mean encoding to the entire dataset
        df[f'{col}_encoded'] = df[col].map(target_mean)

        # Handle missing values for categories not present in training
        df[f'{col}_encoded'].fillna(df[target_column].mean(), inplace=True)

    return df

# Example usage: Apply Target Encoding to multiple columns
categorical_columns = ['month', 'day', 'year', 'day_of_week']
df = target_encoding_multiple_columns(df, target_column='sales', categorical_columns=categorical_columns)


# Drop unnecessary columns after encoding
columns_to_drop = [
    'locale_name', 'description', 'transferred', 'city', 'state', 'family',
    'month', 'day_of_week', 'day', 'year', 'cluster', 'type'
]
df.drop(columns=columns_to_drop, errors='ignore', inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'date', 'sales', 'onpromotion', 'dataset', 'dcoilwtico',
#        'transactions', 'is_holiday', 'store_nbr_2', 'store_nbr_3',
#        'store_nbr_4', 'store_nbr_5', 'store_nbr_6', 'store_nbr_7',
#        'store_nbr_8', 'store_nbr_9', 'store_nbr_10', 'store_nbr_11',
#        'store_nbr_12', 'store_nbr_13', 'store_nbr_14', 'store_nbr_15',
#        'store_nbr_16', 'store_nbr_17', 'store_nbr_18', 'store_nbr_19',
#        'store_nbr_20', 'store_nbr_21', 'store_nbr_22', 'store_nbr_23',
#        'store_nbr_24', 'store_nbr_25', 'store_nbr_26', 'store_nbr_27',
#        'store_nbr_28', 'store_nbr_29', 'store_nbr_30', 'store_nbr_31',
#        'store_nbr_32', 'store_nbr_33', 'store_nbr_34', 'store_nbr_35',
#        'store_nbr_36', 'store_nbr_37', 'store_nbr_38', 'store_nbr_39',
#        'store_nbr_40', 'store_nbr_41', 'store_nbr_42', 'store_nbr_43',
#        'store_nbr_44', 'store_nbr_45', 'store_nbr_46', 'store_nbr_47',
#        'store_nbr_48', 'store_nbr_49', 'store_nbr_50', 'store_nbr_51',
#        'store_nbr_52', 'store_nbr_53', 'store_nbr_54', 'family_BABY CARE',
#        'family_BEAUTY', 'family_BEVERAGES', 'family_BOOKS',
#        'family_BREAD/BAKERY', 'family_CELEBRATION', 'family_CLEANING',
#        'family_DAIRY', 'family_DELI', 'family_EGGS', 'family_FROZEN FOODS',
#        'family_GROCERY I', 'family_GROCERY II', 'family_HARDWARE',
#        'family_HOME AND KITCHEN I', 'family_HOME AND KITCHEN II',
#        'family_HOME APPLIANCES', 'family_HOME CARE', 'family_LADIESWEAR',
#        'family_LAWN AND GARDEN', 'family_LINGERIE', 'family_LIQUOR,WINE,BEER',
#        'family_MAGAZINES', 'family_MEATS', 'family_PERSONAL CARE',
#        'family_PET SUPPLIES', 'family_PLAYERS AND ELECTRONICS',
#        'family_POULTRY', 'family_PREPARED FOODS', 'family_PRODUCE',
#        'family_SCHOOL AND OFFICE SUPPLIES', 'family_SEAFOOD', 'month_encoded',
#        'day_encoded', 'year_encoded', 'day_of_week_encoded'],
#       dtype='object')

# %% [markdown]
# ## 2.4: Split Data Back into Train and Test Sets

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Step 5: Split Data Based on Time Series Order

# Separate train and test datasets
train_df = df[df['dataset'] == 'train'].drop(columns=['dataset'], errors='ignore')
test_df = df[df['dataset'] == 'test'].drop(columns=['dataset'], errors='ignore')


# Drop unnecessary columns from both datasets
train_df = train_df.drop(columns=['transactions', 'id'], errors='ignore')
test_df = test_df.drop(columns=['transactions'], errors='ignore')

# Sort training data by date to preserve time series order
train_df = train_df.sort_values(by='date')

# Define the split point for time series validation
split_ratio = 0.99  # Adjust as needed
split_index = int(len(train_df) * split_ratio)

# Create training and validation sets
X_train = train_df.iloc[:split_index].drop(columns=['sales'])
y_train = train_df.iloc[:split_index]['sales']
X_val = train_df.iloc[split_index:].drop(columns=['sales'])
y_val = train_df.iloc[split_index:]['sales']

# Log transform the target variables to stabilize variance
y_train = np.log1p(y_train)  # Log transform training target
y_val = np.log1p(y_val)      # Log transform validation target

# Drop the 'date' column after feature extraction
X_train = X_train.drop(columns=['date'], errors='ignore')
X_val = X_val.drop(columns=['date'], errors='ignore')

X_test = test_df.drop(columns=['sales'], errors='ignore')

# %%
X_val
# Out:
#          onpromotion  dcoilwtico  is_holiday  store_nbr_2  store_nbr_3  \
# 3023829            0       49.72           0            0            0
# 3023817            0       49.72           0            0            0
# 3023806            1       49.72           0            0            0
# 3023807            0       49.72           0            0            0
# 3023808           12       49.72           0            0            0
# ...              ...         ...         ...          ...          ...
# 3054345          148       47.57           1            0            0
# 3054346            8       47.57           1            0            0
# 3054347            0       47.57           1            0            0
# 3054322           25       47.57           1            0            0
# 3053163           10       47.57           1            0            0
#
#          store_nbr_4  store_nbr_5  store_nbr_6  store_nbr_7  store_nbr_8  ...  \
# 3023829            0            0            0            0            0  ...
# 3023817            0            0            0            0            0  ...
# 3023806            0            0            0            0            0  ...
# 3023807            0            0            0            0            0  ...
# 3023808            0            0            0            0            0  ...
# ...              ...          ...          ...          ...          ...  ...
# 3054345            0            0            0            0            0  ...
# 3054346            0            0            0            0            0  ...
# 3054347            0            0            0            0            0  ...
# 3054322            0            0            0            0            0  ...
# 3053163            0            0            0            0            0  ...
#
#          family_PLAYERS AND ELECTRONICS  family_POULTRY  \
# 3023829                               0               0
# 3023817                               1               0
# 3023806                               0               0
# 3023807                               0               0
# 3023808                               0               0
# ...                                 ...             ...
# 3054345                               0               0
# 3054346                               0               0
# 3054347                               0               0
# 3054322                               0               0
# 3053163                               0               0
#
#          family_PREPARED FOODS  family_PRODUCE  \
# 3023829                      0               0
# 3023817                      0               0
# 3023806                      0               0
# 3023807                      0               0
# 3023808                      0               0
# ...                        ...             ...
# 3054345                      0               1
# 3054346                      0               0
# 3054347                      0               0
# 3054322                      0               0
# 3053163                      0               0
#
#          family_SCHOOL AND OFFICE SUPPLIES  family_SEAFOOD  month_encoded  \
# 3023829                                  0               0     376.414091
# 3023817                                  0               0     376.414091
# 3023806                                  0               0     376.414091
# 3023807                                  0               0     376.414091
# 3023808                                  0               0     376.414091
# ...                                    ...             ...            ...
# 3054345                                  0               0     336.992535
# 3054346                                  1               0     336.992535
# 3054347                                  0               1     336.992535
# 3054322                                  0               0     336.992535
# 3053163                                  0               0     336.992535
#
#          day_encoded  year_encoded  day_of_week_encoded
# 3023829   345.823234    481.166458           434.785811
# 3023817   345.823234    481.166458           434.785811
# 3023806   345.823234    481.166458           434.785811
# 3023807   345.823234    481.166458           434.785811
# 3023808   345.823234    481.166458           434.785811
# ...              ...           ...                  ...
# 3054345   348.736707    481.166458           319.920782
# 3054346   348.736707    481.166458           319.920782
# 3054347   348.736707    481.166458           319.920782
# 3054322   348.736707    481.166458           319.920782
# 3053163   348.736707    481.166458           319.920782
#
# [30544 rows x 92 columns]

# %% [markdown]
# # 3. Model Selection and Implementation

# %% [markdown]
# ## CatBoost

# %%
# Define train and validation pools
from catboost import CatBoostRegressor, Pool

# Assuming train_pool and val_pool are already defined
train_pool = Pool(X_train, y_train)
val_pool = Pool(X_val, y_val)

# Define the CatBoost model with initial parameters
catboost_model = CatBoostRegressor(
    iterations=10000,          # Total iterations to train
    learning_rate=0.1,        # Learning rate
    depth=8,                  # Tree depth
    loss_function='RMSE',     # Loss function
    eval_metric='RMSE',       # Evaluation metric
    random_seed=42,           # Random seed for reproducibility
    verbose=100,               # Verbose output for every 50 iterations
    early_stopping_rounds=50  # Early stopping if no improvement for 50 rounds
)

# Training loop
train_loop_count = 100  # Number of training stages
init_model = None  # Start without an initial model

for i in range(train_loop_count):
    print(f"\nTraining Stage {i + 1}/{train_loop_count}\n")
    catboost_model.fit(
        train_pool,
        eval_set=val_pool,
        early_stopping_rounds=50,
        verbose=50,
        use_best_model=True,
        init_model=init_model  # Use the model from the previous stage
    )
    # Update the initial model for the next training stage
    init_model = catboost_model

# Final model is stored in catboost_model
# Out:
# Training Stage 1/100
#
# 0:	learn: 2.5592675	test: 2.4468546	best: 2.4468546 (0)	total: 301ms	remaining: 50m 7s
# 50:	learn: 1.2962385	test: 1.0346200	best: 1.0346200 (50)	total: 10.2s	remaining: 33m 11s
# 100:	learn: 1.0727111	test: 0.8925951	best: 0.8925951 (100)	total: 19.4s	remaining: 31m 39s
# 150:	learn: 0.9675240	test: 0.8060438	best: 0.8060438 (150)	total: 28.4s	remaining: 30m 55s
# 200:	learn: 0.9001200	test: 0.7506687	best: 0.7506687 (200)	total: 38s	remaining: 30m 50s
# 250:	learn: 0.8474015	test: 0.7144918	best: 0.7144918 (250)	total: 47s	remaining: 30m 25s
# 300:	learn: 0.8100425	test: 0.6889586	best: 0.6889586 (300)	total: 56s	remaining: 30m 3s
# 350:	learn: 0.7757096	test: 0.6689362	best: 0.6689362 (350)	total: 1m 5s	remaining: 29m 49s
# 400:	learn: 0.7515872	test: 0.6504629	best: 0.6504629 (400)	total: 1m 14s	remaining: 29m 47s
# 450:	learn: 0.7308678	test: 0.6346199	best: 0.6346199 (450)	total: 1m 23s	remaining: 29m 35s
# 500:	learn: 0.7107595	test: 0.6235811	best: 0.6235811 (500)	total: 1m 32s	remaining: 29m 21s
# 550:	learn: 0.6941427	test: 0.6102232	best: 0.6102232 (550)	total: 1m 42s	remaining: 29m 18s
# 600:	learn: 0.6796250	test: 0.6034306	best: 0.6034306 (600)	total: 1m 51s	remaining: 29m 6s
# 650:	learn: 0.6669373	test: 0.5957503	best: 0.5957503 (650)	total: 2m	remaining: 28m 53s
# 700:	learn: 0.6555172	test: 0.5902050	best: 0.5902050 (700)	total: 2m 9s	remaining: 28m 42s
# 750:	learn: 0.6440673	test: 0.5825310	best: 0.5825310 (750)	total: 2m 19s	remaining: 28m 38s
# 800:	learn: 0.6346951	test: 0.5766046	best: 0.5766046 (800)	total: 2m 28s	remaining: 28m 27s
# 850:	learn: 0.6251206	test: 0.5735708	best: 0.5735708 (850)	total: 2m 37s	remaining: 28m 15s
# 900:	learn: 0.6171390	test: 0.5677446	best: 0.5677074 (898)	total: 2m 47s	remaining: 28m 9s
# 950:	learn: 0.6090441	test: 0.5648091	best: 0.5643150 (945)	total: 2m 56s	remaining: 27m 59s
# 1000:	learn: 0.6019477	test: 0.5576463	best: 0.5576463 (1000)	total: 3m 5s	remaining: 27m 51s
# 1050:	learn: 0.5959845	test: 0.5548471	best: 0.5548471 (1050)	total: 3m 15s	remaining: 27m 40s
# 1100:	learn: 0.5892916	test: 0.5514398	best: 0.5512971 (1098)	total: 3m 24s	remaining: 27m 34s
# 1150:	learn: 0.5836775	test: 0.5481489	best: 0.5481489 (1150)	total: 3m 33s	remaining: 27m 23s
# 1200:	learn: 0.5781453	test: 0.5439644	best: 0.5439644 (1200)	total: 3m 42s	remaining: 27m 13s
# 1250:	learn: 0.5729860	test: 0.5386710	best: 0.5386710 (1250)	total: 3m 52s	remaining: 27m 6s
# 1300:	learn: 0.5683135	test: 0.5339532	best: 0.5339532 (1300)	total: 4m 1s	remaining: 26m 56s
# 1350:	learn: 0.5640846	test: 0.5298180	best: 0.5298180 (1350)	total: 4m 10s	remaining: 26m 45s
# 1400:	learn: 0.5592270	test: 0.5275395	best: 0.5275388 (1399)	total: 4m 20s	remaining: 26m 36s
# 1450:	learn: 0.5553000	test: 0.5250972	best: 0.5250972 (1450)	total: 4m 29s	remaining: 26m 27s
# 1500:	learn: 0.5513689	test: 0.5232580	best: 0.5232580 (1500)	total: 4m 38s	remaining: 26m 18s
# 1550:	learn: 0.5474653	test: 0.5214307	best: 0.5214307 (1550)	total: 4m 47s	remaining: 26m 8s
# 1600:	learn: 0.5434198	test: 0.5208701	best: 0.5208701 (1600)	total: 4m 57s	remaining: 26m 1s
# 1650:	learn: 0.5397294	test: 0.5219056	best: 0.5198309 (1629)	total: 5m 6s	remaining: 25m 51s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5198309268
# bestIteration = 1629
#
# Shrink model to first 1630 iterations.
#
# Training Stage 2/100
#
# 0:	learn: 0.5411684	test: 0.5198257	best: 0.5198257 (0)	total: 211ms	remaining: 35m 11s
# 50:	learn: 0.5374661	test: 0.5250188	best: 0.5197823 (2)	total: 9.87s	remaining: 32m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5197823429
# bestIteration = 2
#
# Shrink model to first 3 iterations.
#
# Training Stage 3/100
#
# 0:	learn: 0.5410153	test: 0.5197652	best: 0.5197652 (0)	total: 179ms	remaining: 29m 47s
# 50:	learn: 0.5372793	test: 0.5194920	best: 0.5188270 (30)	total: 9.38s	remaining: 30m 30s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5188270369
# bestIteration = 30
#
# Shrink model to first 31 iterations.
#
# Training Stage 4/100
#
# 0:	learn: 0.5385718	test: 0.5189556	best: 0.5189556 (0)	total: 197ms	remaining: 32m 53s
# 50:	learn: 0.5349438	test: 0.5162327	best: 0.5156982 (47)	total: 9.95s	remaining: 32m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5156981983
# bestIteration = 47
#
# Shrink model to first 48 iterations.
#
# Training Stage 5/100
#
# 0:	learn: 0.5350880	test: 0.5150105	best: 0.5150105 (0)	total: 190ms	remaining: 31m 38s
# 50:	learn: 0.5314214	test: 0.5136696	best: 0.5136696 (50)	total: 9.51s	remaining: 30m 54s
# 100:	learn: 0.5284695	test: 0.5134058	best: 0.5134058 (100)	total: 19s	remaining: 31m 5s
# 150:	learn: 0.5256739	test: 0.5116101	best: 0.5115810 (149)	total: 28.1s	remaining: 30m 30s
# 200:	learn: 0.5230811	test: 0.5079785	best: 0.5079785 (200)	total: 37.1s	remaining: 30m 9s
# 250:	learn: 0.5207010	test: 0.5064194	best: 0.5064194 (250)	total: 46.7s	remaining: 30m 13s
# 300:	learn: 0.5183498	test: 0.5050827	best: 0.5049885 (294)	total: 55.8s	remaining: 29m 57s
# 350:	learn: 0.5157450	test: 0.5036926	best: 0.5036926 (350)	total: 1m 4s	remaining: 29m 43s
# 400:	learn: 0.5136479	test: 0.5001800	best: 0.5001800 (400)	total: 1m 14s	remaining: 29m 43s
# 450:	learn: 0.5110149	test: 0.4987273	best: 0.4986620 (449)	total: 1m 23s	remaining: 29m 32s
# 500:	learn: 0.5085891	test: 0.4969287	best: 0.4969287 (500)	total: 1m 32s	remaining: 29m 20s
# 550:	learn: 0.5063793	test: 0.4965348	best: 0.4964065 (546)	total: 1m 41s	remaining: 29m 8s
# 600:	learn: 0.5043218	test: 0.4958840	best: 0.4957509 (596)	total: 1m 51s	remaining: 29m 4s
# 650:	learn: 0.5023200	test: 0.4952301	best: 0.4952301 (650)	total: 2m	remaining: 28m 53s
# 700:	learn: 0.5005204	test: 0.4946580	best: 0.4946580 (700)	total: 2m 9s	remaining: 28m 41s
# 750:	learn: 0.4986536	test: 0.4933651	best: 0.4933185 (726)	total: 2m 19s	remaining: 28m 36s
# 800:	learn: 0.4965462	test: 0.4921146	best: 0.4910712 (771)	total: 2m 28s	remaining: 28m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4910711587
# bestIteration = 771
#
# Shrink model to first 772 iterations.
#
# Training Stage 6/100
#
# 0:	learn: 0.4979058	test: 0.4910311	best: 0.4910311 (0)	total: 180ms	remaining: 29m 59s
# 50:	learn: 0.4954656	test: 0.4916623	best: 0.4908785 (4)	total: 9.45s	remaining: 30m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4908784733
# bestIteration = 4
#
# Shrink model to first 5 iterations.
#
# Training Stage 7/100
#
# 0:	learn: 0.4976482	test: 0.4909405	best: 0.4909405 (0)	total: 188ms	remaining: 31m 18s
# 50:	learn: 0.4954391	test: 0.4908653	best: 0.4907938 (6)	total: 9.56s	remaining: 31m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4907938064
# bestIteration = 6
#
# Shrink model to first 7 iterations.
#
# Training Stage 8/100
#
# 0:	learn: 0.4973448	test: 0.4907887	best: 0.4907887 (0)	total: 179ms	remaining: 29m 49s
# 50:	learn: 0.4949397	test: 0.4914583	best: 0.4906986 (6)	total: 9.96s	remaining: 32m 22s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4906986295
# bestIteration = 6
#
# Shrink model to first 7 iterations.
#
# Training Stage 9/100
#
# 0:	learn: 0.4969739	test: 0.4906683	best: 0.4906683 (0)	total: 186ms	remaining: 31m
# 50:	learn: 0.4949387	test: 0.4914006	best: 0.4906683 (0)	total: 9.41s	remaining: 30m 35s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4906682828
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 10/100
#
# 0:	learn: 0.4968913	test: 0.4906821	best: 0.4906821 (0)	total: 198ms	remaining: 32m 59s
# 50:	learn: 0.4949035	test: 0.4910048	best: 0.4906230 (2)	total: 9.86s	remaining: 32m 3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.490622976
# bestIteration = 2
#
# Shrink model to first 3 iterations.
#
# Training Stage 11/100
#
# 0:	learn: 0.4968168	test: 0.4906169	best: 0.4906169 (0)	total: 177ms	remaining: 29m 34s
# 50:	learn: 0.4947276	test: 0.4909462	best: 0.4905770 (1)	total: 9.33s	remaining: 30m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4905769517
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 12/100
#
# 0:	learn: 0.4967562	test: 0.4905796	best: 0.4905796 (0)	total: 178ms	remaining: 29m 39s
# 50:	learn: 0.4946778	test: 0.4905031	best: 0.4905031 (50)	total: 9.85s	remaining: 32m
# 100:	learn: 0.4925605	test: 0.4907640	best: 0.4900138 (97)	total: 19.1s	remaining: 31m 9s
# 150:	learn: 0.4907224	test: 0.4898444	best: 0.4898443 (148)	total: 28.3s	remaining: 30m 44s
# 200:	learn: 0.4891861	test: 0.4907613	best: 0.4892570 (190)	total: 37.8s	remaining: 30m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.489257045
# bestIteration = 190
#
# Shrink model to first 191 iterations.
#
# Training Stage 13/100
#
# 0:	learn: 0.4894460	test: 0.4892600	best: 0.4892600 (0)	total: 200ms	remaining: 33m 15s
# 50:	learn: 0.4878401	test: 0.4884613	best: 0.4884613 (50)	total: 9.35s	remaining: 30m 24s
# 100:	learn: 0.4858733	test: 0.4910134	best: 0.4883842 (57)	total: 19.2s	remaining: 31m 17s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4883842342
# bestIteration = 57
#
# Shrink model to first 58 iterations.
#
# Training Stage 14/100
#
# 0:	learn: 0.4875980	test: 0.4883455	best: 0.4883455 (0)	total: 195ms	remaining: 32m 33s
# 50:	learn: 0.4859146	test: 0.4907190	best: 0.4880148 (33)	total: 9.41s	remaining: 30m 35s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4880148114
# bestIteration = 33
#
# Shrink model to first 34 iterations.
#
# Training Stage 15/100
#
# 0:	learn: 0.4864484	test: 0.4879751	best: 0.4879751 (0)	total: 191ms	remaining: 31m 47s
# 50:	learn: 0.4846942	test: 0.4877245	best: 0.4877245 (50)	total: 9.73s	remaining: 31m 37s
# 100:	learn: 0.4830878	test: 0.4888347	best: 0.4875330 (79)	total: 19s	remaining: 31m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4875329853
# bestIteration = 79
#
# Shrink model to first 80 iterations.
#
# Training Stage 16/100
#
# 0:	learn: 0.4837090	test: 0.4874997	best: 0.4874997 (0)	total: 190ms	remaining: 31m 42s
# 50:	learn: 0.4821930	test: 0.4850560	best: 0.4850560 (50)	total: 9.55s	remaining: 31m 2s
# 100:	learn: 0.4805106	test: 0.4864777	best: 0.4848450 (76)	total: 18.9s	remaining: 30m 54s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4848450284
# bestIteration = 76
#
# Shrink model to first 77 iterations.
#
# Training Stage 17/100
#
# 0:	learn: 0.4811947	test: 0.4848409	best: 0.4848409 (0)	total: 189ms	remaining: 31m 29s
# 50:	learn: 0.4794505	test: 0.4843774	best: 0.4843774 (50)	total: 9.48s	remaining: 30m 49s
# 100:	learn: 0.4778426	test: 0.4876833	best: 0.4843224 (53)	total: 18.8s	remaining: 30m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.484322352
# bestIteration = 53
#
# Shrink model to first 54 iterations.
#
# Training Stage 18/100
#
# 0:	learn: 0.4793292	test: 0.4843334	best: 0.4843334 (0)	total: 238ms	remaining: 39m 38s
# 50:	learn: 0.4781734	test: 0.4846282	best: 0.4841774 (23)	total: 9.58s	remaining: 31m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.484177392
# bestIteration = 23
#
# Shrink model to first 24 iterations.
#
# Training Stage 19/100
#
# 0:	learn: 0.4788084	test: 0.4841831	best: 0.4841831 (0)	total: 192ms	remaining: 31m 55s
# 50:	learn: 0.4773070	test: 0.4844380	best: 0.4840109 (23)	total: 9.71s	remaining: 31m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4840108564
# bestIteration = 23
#
# Shrink model to first 24 iterations.
#
# Training Stage 20/100
#
# 0:	learn: 0.4781438	test: 0.4839925	best: 0.4839925 (0)	total: 185ms	remaining: 30m 52s
# 50:	learn: 0.4766311	test: 0.4844686	best: 0.4836880 (21)	total: 9.43s	remaining: 30m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4836879942
# bestIteration = 21
#
# Shrink model to first 22 iterations.
#
# Training Stage 21/100
#
# 0:	learn: 0.4774067	test: 0.4836845	best: 0.4836845 (0)	total: 181ms	remaining: 30m 6s
# 50:	learn: 0.4760671	test: 0.4836947	best: 0.4831404 (20)	total: 9.4s	remaining: 30m 33s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.483140439
# bestIteration = 20
#
# Shrink model to first 21 iterations.
#
# Training Stage 22/100
#
# 0:	learn: 0.4768331	test: 0.4831593	best: 0.4831593 (0)	total: 186ms	remaining: 30m 55s
# 50:	learn: 0.4755166	test: 0.4834322	best: 0.4830037 (45)	total: 9.9s	remaining: 32m 11s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4830037069
# bestIteration = 45
#
# Shrink model to first 46 iterations.
#
# Training Stage 23/100
#
# 0:	learn: 0.4756215	test: 0.4829620	best: 0.4829620 (0)	total: 191ms	remaining: 31m 48s
# 50:	learn: 0.4742237	test: 0.4835831	best: 0.4827307 (42)	total: 9.38s	remaining: 30m 29s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4827306723
# bestIteration = 42
#
# Shrink model to first 43 iterations.
#
# Training Stage 24/100
#
# 0:	learn: 0.4744033	test: 0.4826970	best: 0.4826970 (0)	total: 187ms	remaining: 31m 14s
# 50:	learn: 0.4731417	test: 0.4837855	best: 0.4826639 (2)	total: 9.42s	remaining: 30m 37s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4826639012
# bestIteration = 2
#
# Shrink model to first 3 iterations.
#
# Training Stage 25/100
#
# 0:	learn: 0.4743480	test: 0.4826611	best: 0.4826611 (0)	total: 189ms	remaining: 31m 26s
# 50:	learn: 0.4729979	test: 0.4835754	best: 0.4826570 (1)	total: 9.95s	remaining: 32m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4826569944
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 26/100
#
# 0:	learn: 0.4743054	test: 0.4826484	best: 0.4826484 (0)	total: 184ms	remaining: 30m 39s
# 50:	learn: 0.4729110	test: 0.4832613	best: 0.4826302 (1)	total: 9.45s	remaining: 30m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4826302312
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 27/100
#
# 0:	learn: 0.4742751	test: 0.4826104	best: 0.4826104 (0)	total: 181ms	remaining: 30m 8s
# 50:	learn: 0.4729348	test: 0.4838712	best: 0.4825833 (1)	total: 9.46s	remaining: 30m 45s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4825832843
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 28/100
#
# 0:	learn: 0.4742329	test: 0.4825459	best: 0.4825459 (0)	total: 195ms	remaining: 32m 28s
# 50:	learn: 0.4728815	test: 0.4843538	best: 0.4825360 (1)	total: 9.47s	remaining: 30m 47s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4825360293
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 29/100
#
# 0:	learn: 0.4742099	test: 0.4825365	best: 0.4825365 (0)	total: 186ms	remaining: 30m 59s
# 50:	learn: 0.4728677	test: 0.4836294	best: 0.4825365 (0)	total: 9.37s	remaining: 30m 27s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4825364879
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 30/100
#
# 0:	learn: 0.4741980	test: 0.4825348	best: 0.4825348 (0)	total: 184ms	remaining: 30m 39s
# 50:	learn: 0.4728325	test: 0.4823753	best: 0.4823753 (50)	total: 9.76s	remaining: 31m 44s
# 100:	learn: 0.4714751	test: 0.4821630	best: 0.4821243 (78)	total: 19.3s	remaining: 31m 29s
# 150:	learn: 0.4701647	test: 0.4810272	best: 0.4809744 (135)	total: 28.5s	remaining: 31m
# 200:	learn: 0.4690975	test: 0.4819777	best: 0.4809218 (161)	total: 37.7s	remaining: 30m 36s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4809217919
# bestIteration = 161
#
# Shrink model to first 162 iterations.
#
# Training Stage 31/100
#
# 0:	learn: 0.4699229	test: 0.4809051	best: 0.4809051 (0)	total: 186ms	remaining: 31m 1s
# 50:	learn: 0.4686887	test: 0.4797863	best: 0.4797720 (49)	total: 9.48s	remaining: 30m 49s
# 100:	learn: 0.4674313	test: 0.4794959	best: 0.4794930 (99)	total: 18.7s	remaining: 30m 37s
# 150:	learn: 0.4662892	test: 0.4815343	best: 0.4791058 (132)	total: 28.5s	remaining: 30m 57s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4791057614
# bestIteration = 132
#
# Shrink model to first 133 iterations.
#
# Training Stage 32/100
#
# 0:	learn: 0.4666156	test: 0.4790877	best: 0.4790877 (0)	total: 196ms	remaining: 32m 35s
# 50:	learn: 0.4654574	test: 0.4787519	best: 0.4787519 (50)	total: 9.45s	remaining: 30m 43s
# 100:	learn: 0.4643713	test: 0.4816834	best: 0.4784174 (69)	total: 19.2s	remaining: 31m 24s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4784173696
# bestIteration = 69
#
# Shrink model to first 70 iterations.
#
# Training Stage 33/100
#
# 0:	learn: 0.4650534	test: 0.4784005	best: 0.4784005 (0)	total: 187ms	remaining: 31m 5s
# 50:	learn: 0.4640105	test: 0.4789770	best: 0.4780836 (17)	total: 9.47s	remaining: 30m 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.478083569
# bestIteration = 17
#
# Shrink model to first 18 iterations.
#
# Training Stage 34/100
#
# 0:	learn: 0.4646808	test: 0.4780830	best: 0.4780830 (0)	total: 180ms	remaining: 30m 1s
# 50:	learn: 0.4635408	test: 0.4789340	best: 0.4779913 (16)	total: 9.45s	remaining: 30m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4779913488
# bestIteration = 16
#
# Shrink model to first 17 iterations.
#
# Training Stage 35/100
#
# 0:	learn: 0.4642090	test: 0.4779800	best: 0.4779800 (0)	total: 183ms	remaining: 30m 32s
# 50:	learn: 0.4630640	test: 0.4799855	best: 0.4777794 (13)	total: 9.95s	remaining: 32m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4777794338
# bestIteration = 13
#
# Shrink model to first 14 iterations.
#
# Training Stage 36/100
#
# 0:	learn: 0.4639295	test: 0.4777228	best: 0.4777228 (0)	total: 188ms	remaining: 31m 20s
# 50:	learn: 0.4629949	test: 0.4775171	best: 0.4774960 (48)	total: 9.39s	remaining: 30m 32s
# 100:	learn: 0.4616725	test: 0.4780346	best: 0.4774044 (97)	total: 19.3s	remaining: 31m 27s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4774044189
# bestIteration = 97
#
# Shrink model to first 98 iterations.
#
# Training Stage 37/100
#
# 0:	learn: 0.4617314	test: 0.4773549	best: 0.4773549 (0)	total: 195ms	remaining: 32m 26s
# 50:	learn: 0.4605015	test: 0.4785557	best: 0.4772820 (8)	total: 9.42s	remaining: 30m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.477282003
# bestIteration = 8
#
# Shrink model to first 9 iterations.
#
# Training Stage 38/100
#
# 0:	learn: 0.4615603	test: 0.4772636	best: 0.4772636 (0)	total: 210ms	remaining: 35m 2s
# 50:	learn: 0.4603735	test: 0.4781385	best: 0.4772424 (8)	total: 9.42s	remaining: 30m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.477242371
# bestIteration = 8
#
# Shrink model to first 9 iterations.
#
# Training Stage 39/100
#
# 0:	learn: 0.4614107	test: 0.4772392	best: 0.4772392 (0)	total: 182ms	remaining: 30m 22s
# 50:	learn: 0.4602996	test: 0.4783617	best: 0.4771762 (16)	total: 9.97s	remaining: 32m 24s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4771762119
# bestIteration = 16
#
# Shrink model to first 17 iterations.
#
# Training Stage 40/100
#
# 0:	learn: 0.4610797	test: 0.4771792	best: 0.4771792 (0)	total: 176ms	remaining: 29m 23s
# 50:	learn: 0.4599096	test: 0.4774690	best: 0.4771643 (8)	total: 9.36s	remaining: 30m 26s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4771643211
# bestIteration = 8
#
# Shrink model to first 9 iterations.
#
# Training Stage 41/100
#
# 0:	learn: 0.4608739	test: 0.4771604	best: 0.4771604 (0)	total: 186ms	remaining: 31m 1s
# 50:	learn: 0.4598366	test: 0.4769626	best: 0.4769626 (50)	total: 9.54s	remaining: 31m
# 100:	learn: 0.4587993	test: 0.4772032	best: 0.4766448 (72)	total: 18.9s	remaining: 30m 52s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4766447797
# bestIteration = 72
#
# Shrink model to first 73 iterations.
#
# Training Stage 42/100
#
# 0:	learn: 0.4593296	test: 0.4766206	best: 0.4766206 (0)	total: 194ms	remaining: 32m 14s
# 50:	learn: 0.4582870	test: 0.4771731	best: 0.4765910 (5)	total: 9.47s	remaining: 30m 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4765909888
# bestIteration = 5
#
# Shrink model to first 6 iterations.
#
# Training Stage 43/100
#
# 0:	learn: 0.4592176	test: 0.4765799	best: 0.4765799 (0)	total: 186ms	remaining: 30m 59s
# 50:	learn: 0.4582158	test: 0.4761793	best: 0.4761793 (50)	total: 9.89s	remaining: 32m 10s
# 100:	learn: 0.4571691	test: 0.4791513	best: 0.4761138 (62)	total: 19.2s	remaining: 31m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4761138279
# bestIteration = 62
#
# Shrink model to first 63 iterations.
#
# Training Stage 44/100
#
# 0:	learn: 0.4579790	test: 0.4761103	best: 0.4761103 (0)	total: 182ms	remaining: 30m 22s
# 50:	learn: 0.4569847	test: 0.4769015	best: 0.4760935 (3)	total: 9.85s	remaining: 32m
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4760935405
# bestIteration = 3
#
# Shrink model to first 4 iterations.
#
# Training Stage 45/100
#
# 0:	learn: 0.4578901	test: 0.4760932	best: 0.4760932 (0)	total: 180ms	remaining: 30m 4s
# 50:	learn: 0.4568712	test: 0.4772117	best: 0.4760903 (1)	total: 9.4s	remaining: 30m 33s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4760902672
# bestIteration = 1
#
# Shrink model to first 2 iterations.
#
# Training Stage 46/100
#
# 0:	learn: 0.4578557	test: 0.4760837	best: 0.4760837 (0)	total: 184ms	remaining: 30m 37s
# 50:	learn: 0.4569618	test: 0.4765131	best: 0.4760837 (0)	total: 9.89s	remaining: 32m 9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4760837089
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 47/100
#
# 0:	learn: 0.4578460	test: 0.4760811	best: 0.4760811 (0)	total: 207ms	remaining: 34m 29s
# 50:	learn: 0.4568973	test: 0.4760871	best: 0.4760410 (39)	total: 9.36s	remaining: 30m 25s
# 100:	learn: 0.4559542	test: 0.4758996	best: 0.4758655 (80)	total: 19.1s	remaining: 31m 9s
# 150:	learn: 0.4549702	test: 0.4758017	best: 0.4756514 (124)	total: 28.2s	remaining: 30m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4756513643
# bestIteration = 124
#
# Shrink model to first 125 iterations.
#
# Training Stage 48/100
#
# 0:	learn: 0.4555373	test: 0.4756456	best: 0.4756456 (0)	total: 184ms	remaining: 30m 39s
# 50:	learn: 0.4545819	test: 0.4764448	best: 0.4756018 (8)	total: 9.94s	remaining: 32m 18s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4756017922
# bestIteration = 8
#
# Shrink model to first 9 iterations.
#
# Training Stage 49/100
#
# 0:	learn: 0.4554105	test: 0.4756065	best: 0.4756065 (0)	total: 186ms	remaining: 31m 4s
# 50:	learn: 0.4544908	test: 0.4753130	best: 0.4753130 (50)	total: 9.37s	remaining: 30m 27s
# 100:	learn: 0.4534597	test: 0.4769414	best: 0.4753130 (50)	total: 19.2s	remaining: 31m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4753129526
# bestIteration = 50
#
# Shrink model to first 51 iterations.
#
# Training Stage 50/100
#
# 0:	learn: 0.4544841	test: 0.4753086	best: 0.4753086 (0)	total: 186ms	remaining: 30m 57s
# 50:	learn: 0.4535971	test: 0.4751263	best: 0.4751227 (43)	total: 9.41s	remaining: 30m 35s
# 100:	learn: 0.4525373	test: 0.4769015	best: 0.4750933 (56)	total: 18.7s	remaining: 30m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4750932882
# bestIteration = 56
#
# Shrink model to first 57 iterations.
#
# Training Stage 51/100
#
# 0:	learn: 0.4534859	test: 0.4750942	best: 0.4750942 (0)	total: 182ms	remaining: 30m 14s
# 50:	learn: 0.4525744	test: 0.4749175	best: 0.4749175 (50)	total: 9.4s	remaining: 30m 33s
# 100:	learn: 0.4517504	test: 0.4749625	best: 0.4748798 (54)	total: 18.7s	remaining: 30m 29s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4748797795
# bestIteration = 54
#
# Shrink model to first 55 iterations.
#
# Training Stage 52/100
#
# 0:	learn: 0.4525217	test: 0.4748547	best: 0.4748547 (0)	total: 190ms	remaining: 31m 39s
# 50:	learn: 0.4516214	test: 0.4747946	best: 0.4745420 (17)	total: 9.38s	remaining: 30m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4745419836
# bestIteration = 17
#
# Shrink model to first 18 iterations.
#
# Training Stage 53/100
#
# 0:	learn: 0.4522231	test: 0.4745378	best: 0.4745378 (0)	total: 204ms	remaining: 34m
# 50:	learn: 0.4513331	test: 0.4732650	best: 0.4732117 (43)	total: 9.95s	remaining: 32m 20s
# 100:	learn: 0.4504810	test: 0.4730087	best: 0.4729829 (95)	total: 19.2s	remaining: 31m 17s
# 150:	learn: 0.4495326	test: 0.4734336	best: 0.4729675 (106)	total: 28.3s	remaining: 30m 45s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4729674998
# bestIteration = 106
#
# Shrink model to first 107 iterations.
#
# Training Stage 54/100
#
# 0:	learn: 0.4503953	test: 0.4729411	best: 0.4729411 (0)	total: 179ms	remaining: 29m 48s
# 50:	learn: 0.4496140	test: 0.4733507	best: 0.4728108 (12)	total: 9.3s	remaining: 30m 14s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4728107881
# bestIteration = 12
#
# Shrink model to first 13 iterations.
#
# Training Stage 55/100
#
# 0:	learn: 0.4502002	test: 0.4728010	best: 0.4728010 (0)	total: 182ms	remaining: 30m 20s
# 50:	learn: 0.4493890	test: 0.4718841	best: 0.4718841 (50)	total: 9.9s	remaining: 32m 12s
# 100:	learn: 0.4485099	test: 0.4719226	best: 0.4717584 (83)	total: 19.2s	remaining: 31m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.471758412
# bestIteration = 83
#
# Shrink model to first 84 iterations.
#
# Training Stage 56/100
#
# 0:	learn: 0.4487883	test: 0.4716661	best: 0.4716661 (0)	total: 190ms	remaining: 31m 37s
# 50:	learn: 0.4480999	test: 0.4713676	best: 0.4713501 (49)	total: 10s	remaining: 32m 36s
# 100:	learn: 0.4473194	test: 0.4714173	best: 0.4712903 (67)	total: 19.4s	remaining: 31m 40s
# 150:	learn: 0.4464461	test: 0.4709737	best: 0.4709246 (143)	total: 28.8s	remaining: 31m 18s
# 200:	learn: 0.4456743	test: 0.4709940	best: 0.4708710 (178)	total: 38.6s	remaining: 31m 20s
# 250:	learn: 0.4448939	test: 0.4705634	best: 0.4704099 (230)	total: 47.9s	remaining: 31m 1s
# 300:	learn: 0.4441442	test: 0.4754158	best: 0.4703285 (278)	total: 57.2s	remaining: 30m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703284658
# bestIteration = 278
#
# Shrink model to first 279 iterations.
#
# Training Stage 57/100
#
# 0:	learn: 0.4444629	test: 0.4703545	best: 0.4703545 (0)	total: 202ms	remaining: 33m 41s
# 50:	learn: 0.4437410	test: 0.4713359	best: 0.4703545 (0)	total: 9.56s	remaining: 31m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703544727
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 58/100
#
# 0:	learn: 0.4444582	test: 0.4703520	best: 0.4703520 (0)	total: 179ms	remaining: 29m 49s
# 50:	learn: 0.4437212	test: 0.4712232	best: 0.4703520 (0)	total: 9.97s	remaining: 32m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.470351969
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 59/100
#
# 0:	learn: 0.4444502	test: 0.4703454	best: 0.4703454 (0)	total: 178ms	remaining: 29m 37s
# 50:	learn: 0.4437031	test: 0.4708826	best: 0.4703454 (0)	total: 9.46s	remaining: 30m 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703453856
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 60/100
#
# 0:	learn: 0.4444383	test: 0.4703427	best: 0.4703427 (0)	total: 190ms	remaining: 31m 39s
# 50:	learn: 0.4436968	test: 0.4710294	best: 0.4703427 (0)	total: 9.48s	remaining: 30m 49s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703426635
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 61/100
#
# 0:	learn: 0.4444013	test: 0.4703409	best: 0.4703409 (0)	total: 192ms	remaining: 32m
# 50:	learn: 0.4437101	test: 0.4712698	best: 0.4703409 (0)	total: 9.7s	remaining: 31m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703408887
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 62/100
#
# 0:	learn: 0.4443969	test: 0.4703066	best: 0.4703066 (0)	total: 185ms	remaining: 30m 53s
# 50:	learn: 0.4436311	test: 0.4713889	best: 0.4703066 (0)	total: 9.36s	remaining: 30m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703066154
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 63/100
#
# 0:	learn: 0.4443903	test: 0.4703075	best: 0.4703075 (0)	total: 197ms	remaining: 32m 45s
# 50:	learn: 0.4436538	test: 0.4713818	best: 0.4703075 (0)	total: 10s	remaining: 32m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703074689
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 64/100
#
# 0:	learn: 0.4443840	test: 0.4703017	best: 0.4703017 (0)	total: 189ms	remaining: 31m 32s
# 50:	learn: 0.4436567	test: 0.4712161	best: 0.4703017 (0)	total: 9.47s	remaining: 30m 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.470301656
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 65/100
#
# 0:	learn: 0.4443767	test: 0.4703016	best: 0.4703016 (0)	total: 190ms	remaining: 31m 40s
# 50:	learn: 0.4436329	test: 0.4711621	best: 0.4703016 (0)	total: 9.57s	remaining: 31m 6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703016428
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 66/100
#
# 0:	learn: 0.4443701	test: 0.4702984	best: 0.4702984 (0)	total: 190ms	remaining: 31m 40s
# 50:	learn: 0.4436231	test: 0.4715278	best: 0.4702984 (0)	total: 10s	remaining: 32m 31s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702984327
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 67/100
#
# 0:	learn: 0.4443652	test: 0.4702982	best: 0.4702982 (0)	total: 188ms	remaining: 31m 15s
# 50:	learn: 0.4435899	test: 0.4714153	best: 0.4702982 (0)	total: 9.33s	remaining: 30m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702982302
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 68/100
#
# 0:	learn: 0.4443470	test: 0.4703007	best: 0.4703007 (0)	total: 189ms	remaining: 31m 24s
# 50:	learn: 0.4435710	test: 0.4713506	best: 0.4703007 (0)	total: 9.34s	remaining: 30m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4703007134
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 69/100
#
# 0:	learn: 0.4443280	test: 0.4702862	best: 0.4702862 (0)	total: 190ms	remaining: 31m 41s
# 50:	learn: 0.4435870	test: 0.4713670	best: 0.4702862 (0)	total: 9.3s	remaining: 30m 14s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702862235
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 70/100
#
# 0:	learn: 0.4443181	test: 0.4702920	best: 0.4702920 (0)	total: 183ms	remaining: 30m 32s
# 50:	learn: 0.4435013	test: 0.4715642	best: 0.4702920 (0)	total: 9.31s	remaining: 30m 16s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.470292001
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 71/100
#
# 0:	learn: 0.4443111	test: 0.4702926	best: 0.4702926 (0)	total: 190ms	remaining: 31m 36s
# 50:	learn: 0.4435327	test: 0.4715489	best: 0.4702926 (0)	total: 9.84s	remaining: 31m 58s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702925574
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 72/100
#
# 0:	learn: 0.4443029	test: 0.4702666	best: 0.4702666 (0)	total: 188ms	remaining: 31m 17s
# 50:	learn: 0.4435176	test: 0.4713950	best: 0.4702666 (0)	total: 9.32s	remaining: 30m 18s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702665845
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 73/100
#
# 0:	learn: 0.4442938	test: 0.4702459	best: 0.4702459 (0)	total: 186ms	remaining: 31m 4s
# 50:	learn: 0.4435546	test: 0.4711501	best: 0.4702459 (0)	total: 9.33s	remaining: 30m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702458784
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 74/100
#
# 0:	learn: 0.4442601	test: 0.4702724	best: 0.4702724 (0)	total: 187ms	remaining: 31m 9s
# 50:	learn: 0.4435291	test: 0.4711241	best: 0.4702724 (0)	total: 9.87s	remaining: 32m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702723952
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 75/100
#
# 0:	learn: 0.4442522	test: 0.4702605	best: 0.4702605 (0)	total: 185ms	remaining: 30m 48s
# 50:	learn: 0.4434931	test: 0.4711136	best: 0.4702605 (0)	total: 9.34s	remaining: 30m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702604523
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 76/100
#
# 0:	learn: 0.4442344	test: 0.4703050	best: 0.4703050 (0)	total: 255ms	remaining: 42m 32s
# 50:	learn: 0.4434885	test: 0.4706354	best: 0.4702607 (16)	total: 9.63s	remaining: 31m 18s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4702607443
# bestIteration = 16
#
# Shrink model to first 17 iterations.
#
# Training Stage 77/100
#
# 0:	learn: 0.4439467	test: 0.4702919	best: 0.4702919 (0)	total: 185ms	remaining: 30m 52s
# 50:	learn: 0.4432533	test: 0.4700809	best: 0.4700809 (50)	total: 9.85s	remaining: 32m 1s
# 100:	learn: 0.4424367	test: 0.4709288	best: 0.4700635 (65)	total: 19.2s	remaining: 31m 18s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4700635072
# bestIteration = 65
#
# Shrink model to first 66 iterations.
#
# Training Stage 78/100
#
# 0:	learn: 0.4429343	test: 0.4700614	best: 0.4700614 (0)	total: 184ms	remaining: 30m 42s
# 50:	learn: 0.4422190	test: 0.4702064	best: 0.4700534 (13)	total: 9.86s	remaining: 32m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.470053378
# bestIteration = 13
#
# Shrink model to first 14 iterations.
#
# Training Stage 79/100
#
# 0:	learn: 0.4427729	test: 0.4700418	best: 0.4700418 (0)	total: 179ms	remaining: 29m 49s
# 50:	learn: 0.4420229	test: 0.4702847	best: 0.4697099 (13)	total: 9.34s	remaining: 30m 22s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4697099348
# bestIteration = 13
#
# Shrink model to first 14 iterations.
#
# Training Stage 80/100
#
# 0:	learn: 0.4425374	test: 0.4697065	best: 0.4697065 (0)	total: 177ms	remaining: 29m 28s
# 50:	learn: 0.4418644	test: 0.4706393	best: 0.4697065 (0)	total: 9.33s	remaining: 30m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4697065478
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 81/100
#
# 0:	learn: 0.4425190	test: 0.4697212	best: 0.4697212 (0)	total: 192ms	remaining: 31m 57s
# 50:	learn: 0.4418745	test: 0.4700104	best: 0.4696647 (9)	total: 9.87s	remaining: 32m 6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696646548
# bestIteration = 9
#
# Shrink model to first 10 iterations.
#
# Training Stage 82/100
#
# 0:	learn: 0.4423816	test: 0.4696712	best: 0.4696712 (0)	total: 179ms	remaining: 29m 53s
# 50:	learn: 0.4417292	test: 0.4710359	best: 0.4696712 (0)	total: 9.35s	remaining: 30m 23s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696712321
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 83/100
#
# 0:	learn: 0.4423760	test: 0.4696654	best: 0.4696654 (0)	total: 183ms	remaining: 30m 28s
# 50:	learn: 0.4417754	test: 0.4709186	best: 0.4696654 (0)	total: 9.3s	remaining: 30m 14s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696653636
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 84/100
#
# 0:	learn: 0.4423689	test: 0.4696740	best: 0.4696740 (0)	total: 185ms	remaining: 30m 54s
# 50:	learn: 0.4417178	test: 0.4713714	best: 0.4696740 (0)	total: 9.31s	remaining: 30m 17s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696739545
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 85/100
#
# 0:	learn: 0.4423625	test: 0.4696747	best: 0.4696747 (0)	total: 183ms	remaining: 30m 29s
# 50:	learn: 0.4417026	test: 0.4705605	best: 0.4696747 (0)	total: 9.37s	remaining: 30m 27s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696747441
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 86/100
#
# 0:	learn: 0.4423570	test: 0.4696729	best: 0.4696729 (0)	total: 196ms	remaining: 32m 35s
# 50:	learn: 0.4417375	test: 0.4705870	best: 0.4696729 (0)	total: 9.78s	remaining: 31m 48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696729336
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 87/100
#
# 0:	learn: 0.4423446	test: 0.4696643	best: 0.4696643 (0)	total: 192ms	remaining: 32m 1s
# 50:	learn: 0.4416958	test: 0.4707378	best: 0.4696643 (0)	total: 9.33s	remaining: 30m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696642958
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 88/100
#
# 0:	learn: 0.4423359	test: 0.4696565	best: 0.4696565 (0)	total: 188ms	remaining: 31m 20s
# 50:	learn: 0.4416658	test: 0.4709707	best: 0.4696565 (0)	total: 9.4s	remaining: 30m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696565025
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 89/100
#
# 0:	learn: 0.4423309	test: 0.4696569	best: 0.4696569 (0)	total: 190ms	remaining: 31m 44s
# 50:	learn: 0.4416974	test: 0.4706750	best: 0.4696569 (0)	total: 9.95s	remaining: 32m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696568843
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 90/100
#
# 0:	learn: 0.4423235	test: 0.4696548	best: 0.4696548 (0)	total: 177ms	remaining: 29m 28s
# 50:	learn: 0.4416091	test: 0.4711364	best: 0.4696548 (0)	total: 9.35s	remaining: 30m 23s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4696548136
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 91/100
#
# 0:	learn: 0.4423090	test: 0.4696420	best: 0.4696420 (0)	total: 189ms	remaining: 31m 28s
# 50:	learn: 0.4415900	test: 0.4700935	best: 0.4695994 (3)	total: 9.39s	remaining: 30m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4695993908
# bestIteration = 3
#
# Shrink model to first 4 iterations.
#
# Training Stage 92/100
#
# 0:	learn: 0.4422557	test: 0.4695983	best: 0.4695983 (0)	total: 186ms	remaining: 30m 58s
# 50:	learn: 0.4415779	test: 0.4708750	best: 0.4695983 (0)	total: 9.64s	remaining: 31m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4695983252
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 93/100
#
# 0:	learn: 0.4422500	test: 0.4695831	best: 0.4695831 (0)	total: 184ms	remaining: 30m 35s
# 50:	learn: 0.4416019	test: 0.4713534	best: 0.4695831 (0)	total: 9.39s	remaining: 30m 31s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4695831329
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 94/100
#
# 0:	learn: 0.4422400	test: 0.4694672	best: 0.4694672 (0)	total: 186ms	remaining: 31m 3s
# 50:	learn: 0.4415886	test: 0.4711762	best: 0.4694672 (0)	total: 9.89s	remaining: 32m 10s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4694671664
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 95/100
#
# 0:	learn: 0.4422321	test: 0.4694453	best: 0.4694453 (0)	total: 188ms	remaining: 31m 22s
# 50:	learn: 0.4415908	test: 0.4705176	best: 0.4694453 (0)	total: 9.41s	remaining: 30m 35s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4694452886
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 96/100
#
# 0:	learn: 0.4422243	test: 0.4694143	best: 0.4694143 (0)	total: 179ms	remaining: 29m 52s
# 50:	learn: 0.4416634	test: 0.4702387	best: 0.4694143 (0)	total: 9.36s	remaining: 30m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4694142796
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 97/100
#
# 0:	learn: 0.4422160	test: 0.4694264	best: 0.4694264 (0)	total: 180ms	remaining: 30m 1s
# 50:	learn: 0.4415833	test: 0.4705081	best: 0.4694264 (0)	total: 9.86s	remaining: 32m 3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4694264364
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#
# Training Stage 98/100
#
# 0:	learn: 0.4421923	test: 0.4694018	best: 0.4694018 (0)	total: 186ms	remaining: 31m 2s
# 50:	learn: 0.4415245	test: 0.4698017	best: 0.4693050 (13)	total: 9.48s	remaining: 30m 48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4693049618
# bestIteration = 13
#
# Shrink model to first 14 iterations.
#
# Training Stage 99/100
#
# 0:	learn: 0.4420248	test: 0.4692971	best: 0.4692971 (0)	total: 184ms	remaining: 30m 42s
# 50:	learn: 0.4413457	test: 0.4703158	best: 0.4692866 (6)	total: 9.4s	remaining: 30m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4692865769
# bestIteration = 6
#
# Shrink model to first 7 iterations.
#
# Training Stage 100/100
#
# 0:	learn: 0.4419583	test: 0.4692786	best: 0.4692786 (0)	total: 198ms	remaining: 33m 1s
# 50:	learn: 0.4412995	test: 0.4697691	best: 0.4692324 (6)	total: 9.99s	remaining: 32m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4692324015
# bestIteration = 6
#
# Shrink model to first 7 iterations.

# %%
august_pool = Pool(X_val, y_val)

# %%
for i in range(1):
    catboost_model.fit(august_pool, verbose=50, init_model = catboost_model)
# Out:
# 0:	learn: 0.4636497	total: 4.05ms	remaining: 40.5s
# 50:	learn: 0.4147613	total: 174ms	remaining: 34s
# 100:	learn: 0.4022951	total: 345ms	remaining: 33.8s
# 150:	learn: 0.3909944	total: 514ms	remaining: 33.5s
# 200:	learn: 0.3827195	total: 688ms	remaining: 33.6s
# 250:	learn: 0.3760679	total: 858ms	remaining: 33.3s
# 300:	learn: 0.3704810	total: 1.03s	remaining: 33.2s
# 350:	learn: 0.3654578	total: 1.2s	remaining: 33s
# 400:	learn: 0.3609986	total: 1.37s	remaining: 32.8s
# 450:	learn: 0.3569799	total: 1.54s	remaining: 32.7s
# 500:	learn: 0.3532494	total: 1.73s	remaining: 32.9s
# 550:	learn: 0.3498452	total: 1.9s	remaining: 32.6s
# 600:	learn: 0.3465577	total: 2.07s	remaining: 32.4s
# 650:	learn: 0.3436464	total: 2.24s	remaining: 32.2s
# 700:	learn: 0.3408559	total: 2.42s	remaining: 32.1s
# 750:	learn: 0.3380839	total: 2.59s	remaining: 31.9s
# 800:	learn: 0.3354737	total: 2.76s	remaining: 31.7s
# 850:	learn: 0.3329439	total: 2.93s	remaining: 31.5s
# 900:	learn: 0.3306899	total: 3.11s	remaining: 31.4s
# 950:	learn: 0.3285472	total: 3.31s	remaining: 31.5s
# 1000:	learn: 0.3261894	total: 3.48s	remaining: 31.3s
# 1050:	learn: 0.3241488	total: 3.65s	remaining: 31.1s
# 1100:	learn: 0.3220473	total: 3.82s	remaining: 30.9s
# 1150:	learn: 0.3202182	total: 3.99s	remaining: 30.6s
# 1200:	learn: 0.3182472	total: 4.15s	remaining: 30.4s
# 1250:	learn: 0.3162354	total: 4.32s	remaining: 30.2s
# 1300:	learn: 0.3143987	total: 4.49s	remaining: 30s
# 1350:	learn: 0.3123335	total: 4.66s	remaining: 29.8s
# 1400:	learn: 0.3105104	total: 4.84s	remaining: 29.7s
# 1450:	learn: 0.3087957	total: 5s	remaining: 29.5s
# 1500:	learn: 0.3071253	total: 5.17s	remaining: 29.3s
# 1550:	learn: 0.3052797	total: 5.34s	remaining: 29.1s
# 1600:	learn: 0.3035842	total: 5.52s	remaining: 28.9s
# 1650:	learn: 0.3019043	total: 5.69s	remaining: 28.8s
# 1700:	learn: 0.3002327	total: 5.86s	remaining: 28.6s
# 1750:	learn: 0.2986510	total: 6.03s	remaining: 28.4s
# 1800:	learn: 0.2970661	total: 6.2s	remaining: 28.2s
# 1850:	learn: 0.2956783	total: 6.37s	remaining: 28.1s
# 1900:	learn: 0.2942001	total: 6.54s	remaining: 27.9s
# 1950:	learn: 0.2926437	total: 6.71s	remaining: 27.7s
# 2000:	learn: 0.2911604	total: 6.88s	remaining: 27.5s
# 2050:	learn: 0.2896973	total: 7.05s	remaining: 27.3s
# 2100:	learn: 0.2882851	total: 7.22s	remaining: 27.1s
# 2150:	learn: 0.2869889	total: 7.4s	remaining: 27s
# 2200:	learn: 0.2855979	total: 7.57s	remaining: 26.8s
# 2250:	learn: 0.2842091	total: 7.75s	remaining: 26.7s
# 2300:	learn: 0.2829939	total: 7.92s	remaining: 26.5s
# 2350:	learn: 0.2818330	total: 8.1s	remaining: 26.4s
# 2400:	learn: 0.2804970	total: 8.27s	remaining: 26.2s
# 2450:	learn: 0.2793057	total: 8.44s	remaining: 26s
# 2500:	learn: 0.2780573	total: 8.6s	remaining: 25.8s
# 2550:	learn: 0.2768924	total: 8.77s	remaining: 25.6s
# 2600:	learn: 0.2756436	total: 8.94s	remaining: 25.4s
# 2650:	learn: 0.2744485	total: 9.11s	remaining: 25.3s
# 2700:	learn: 0.2733443	total: 9.28s	remaining: 25.1s
# 2750:	learn: 0.2721399	total: 9.45s	remaining: 24.9s
# 2800:	learn: 0.2710919	total: 9.62s	remaining: 24.7s
# 2850:	learn: 0.2699402	total: 9.79s	remaining: 24.6s
# 2900:	learn: 0.2687876	total: 9.97s	remaining: 24.4s
# 2950:	learn: 0.2676477	total: 10.1s	remaining: 24.2s
# 3000:	learn: 0.2664861	total: 10.3s	remaining: 24s
# 3050:	learn: 0.2654390	total: 10.5s	remaining: 23.9s
# 3100:	learn: 0.2644843	total: 10.6s	remaining: 23.7s
# 3150:	learn: 0.2634650	total: 10.8s	remaining: 23.5s
# 3200:	learn: 0.2624788	total: 11s	remaining: 23.3s
# 3250:	learn: 0.2614551	total: 11.2s	remaining: 23.1s
# 3300:	learn: 0.2604186	total: 11.3s	remaining: 23s
# 3350:	learn: 0.2593866	total: 11.5s	remaining: 22.8s
# 3400:	learn: 0.2583382	total: 11.7s	remaining: 22.6s
# 3450:	learn: 0.2573548	total: 11.8s	remaining: 22.5s
# 3500:	learn: 0.2563131	total: 12s	remaining: 22.3s
# 3550:	learn: 0.2552929	total: 12.2s	remaining: 22.1s
# 3600:	learn: 0.2543470	total: 12.4s	remaining: 22s
# 3650:	learn: 0.2533759	total: 12.5s	remaining: 21.8s
# 3700:	learn: 0.2524317	total: 12.7s	remaining: 21.6s
# 3750:	learn: 0.2515939	total: 12.9s	remaining: 21.5s
# 3800:	learn: 0.2506661	total: 13.1s	remaining: 21.4s
# 3850:	learn: 0.2498200	total: 13.3s	remaining: 21.2s
# 3900:	learn: 0.2489078	total: 13.5s	remaining: 21s
# 3950:	learn: 0.2480175	total: 13.6s	remaining: 20.9s
# 4000:	learn: 0.2471065	total: 13.8s	remaining: 20.7s
# 4050:	learn: 0.2462954	total: 14s	remaining: 20.5s
# 4100:	learn: 0.2453861	total: 14.1s	remaining: 20.3s
# 4150:	learn: 0.2445349	total: 14.3s	remaining: 20.2s
# 4200:	learn: 0.2437450	total: 14.5s	remaining: 20s
# 4250:	learn: 0.2429793	total: 14.6s	remaining: 19.8s
# 4300:	learn: 0.2421680	total: 14.8s	remaining: 19.6s
# 4350:	learn: 0.2414621	total: 15s	remaining: 19.4s
# 4400:	learn: 0.2405959	total: 15.1s	remaining: 19.3s
# 4450:	learn: 0.2397986	total: 15.3s	remaining: 19.1s
# 4500:	learn: 0.2389986	total: 15.5s	remaining: 18.9s
# 4550:	learn: 0.2382516	total: 15.7s	remaining: 18.7s
# 4600:	learn: 0.2374912	total: 15.8s	remaining: 18.6s
# 4650:	learn: 0.2368118	total: 16s	remaining: 18.4s
# 4700:	learn: 0.2360220	total: 16.2s	remaining: 18.2s
# 4750:	learn: 0.2351771	total: 16.3s	remaining: 18s
# 4800:	learn: 0.2344738	total: 16.5s	remaining: 17.9s
# 4850:	learn: 0.2337892	total: 16.7s	remaining: 17.7s
# 4900:	learn: 0.2330526	total: 16.8s	remaining: 17.5s
# 4950:	learn: 0.2323460	total: 17s	remaining: 17.4s
# 5000:	learn: 0.2316189	total: 17.2s	remaining: 17.2s
# 5050:	learn: 0.2309245	total: 17.4s	remaining: 17s
# 5100:	learn: 0.2302767	total: 17.5s	remaining: 16.8s
# 5150:	learn: 0.2295469	total: 17.7s	remaining: 16.7s
# 5200:	learn: 0.2288031	total: 17.9s	remaining: 16.5s
# 5250:	learn: 0.2281258	total: 18s	remaining: 16.3s
# 5300:	learn: 0.2275010	total: 18.2s	remaining: 16.1s
# 5350:	learn: 0.2268053	total: 18.4s	remaining: 16s
# 5400:	learn: 0.2260983	total: 18.5s	remaining: 15.8s
# 5450:	learn: 0.2254346	total: 18.7s	remaining: 15.6s
# 5500:	learn: 0.2247886	total: 18.9s	remaining: 15.4s
# 5550:	learn: 0.2240847	total: 19.1s	remaining: 15.3s
# 5600:	learn: 0.2234118	total: 19.2s	remaining: 15.1s
# 5650:	learn: 0.2228200	total: 19.4s	remaining: 14.9s
# 5700:	learn: 0.2221805	total: 19.6s	remaining: 14.8s
# 5750:	learn: 0.2216230	total: 19.8s	remaining: 14.6s
# 5800:	learn: 0.2209915	total: 19.9s	remaining: 14.4s
# 5850:	learn: 0.2203962	total: 20.1s	remaining: 14.2s
# 5900:	learn: 0.2197786	total: 20.3s	remaining: 14.1s
# 5950:	learn: 0.2191883	total: 20.4s	remaining: 13.9s
# 6000:	learn: 0.2185442	total: 20.6s	remaining: 13.7s
# 6050:	learn: 0.2179257	total: 20.8s	remaining: 13.6s
# 6100:	learn: 0.2173514	total: 20.9s	remaining: 13.4s
# 6150:	learn: 0.2167432	total: 21.1s	remaining: 13.2s
# 6200:	learn: 0.2161673	total: 21.3s	remaining: 13s
# 6250:	learn: 0.2155521	total: 21.5s	remaining: 12.9s
# 6300:	learn: 0.2149615	total: 21.6s	remaining: 12.7s
# 6350:	learn: 0.2143150	total: 21.8s	remaining: 12.5s
# 6400:	learn: 0.2137726	total: 22s	remaining: 12.3s
# 6450:	learn: 0.2132234	total: 22.1s	remaining: 12.2s
# 6500:	learn: 0.2126604	total: 22.3s	remaining: 12s
# 6550:	learn: 0.2120641	total: 22.5s	remaining: 11.8s
# 6600:	learn: 0.2115044	total: 22.6s	remaining: 11.7s
# 6650:	learn: 0.2109290	total: 22.8s	remaining: 11.5s
# 6700:	learn: 0.2104166	total: 23s	remaining: 11.3s
# 6750:	learn: 0.2098710	total: 23.2s	remaining: 11.2s
# 6800:	learn: 0.2093494	total: 23.4s	remaining: 11s
# 6850:	learn: 0.2088616	total: 23.5s	remaining: 10.8s
# 6900:	learn: 0.2083261	total: 23.7s	remaining: 10.6s
# 6950:	learn: 0.2077675	total: 23.9s	remaining: 10.5s
# 7000:	learn: 0.2071927	total: 24s	remaining: 10.3s
# 7050:	learn: 0.2066741	total: 24.2s	remaining: 10.1s
# 7100:	learn: 0.2061167	total: 24.4s	remaining: 9.96s
# 7150:	learn: 0.2056090	total: 24.6s	remaining: 9.8s
# 7200:	learn: 0.2050905	total: 24.8s	remaining: 9.65s
# 7250:	learn: 0.2045327	total: 25s	remaining: 9.49s
# 7300:	learn: 0.2040119	total: 25.3s	remaining: 9.34s
# 7350:	learn: 0.2035174	total: 25.5s	remaining: 9.18s
# 7400:	learn: 0.2030030	total: 25.7s	remaining: 9.02s
# 7450:	learn: 0.2024967	total: 25.9s	remaining: 8.86s
# 7500:	learn: 0.2020021	total: 26.1s	remaining: 8.7s
# 7550:	learn: 0.2015142	total: 26.3s	remaining: 8.53s
# 7600:	learn: 0.2010644	total: 26.5s	remaining: 8.36s
# 7650:	learn: 0.2005928	total: 26.6s	remaining: 8.18s
# 7700:	learn: 0.2000926	total: 26.8s	remaining: 8s
# 7750:	learn: 0.1996203	total: 27s	remaining: 7.83s
# 7800:	learn: 0.1991281	total: 27.2s	remaining: 7.65s
# 7850:	learn: 0.1986358	total: 27.3s	remaining: 7.48s
# 7900:	learn: 0.1981444	total: 27.5s	remaining: 7.3s
# 7950:	learn: 0.1977117	total: 27.7s	remaining: 7.13s
# 8000:	learn: 0.1972181	total: 27.8s	remaining: 6.95s
# 8050:	learn: 0.1967072	total: 28s	remaining: 6.78s
# 8100:	learn: 0.1962260	total: 28.2s	remaining: 6.6s
# 8150:	learn: 0.1958043	total: 28.3s	remaining: 6.43s
# 8200:	learn: 0.1954078	total: 28.5s	remaining: 6.25s
# 8250:	learn: 0.1949489	total: 28.7s	remaining: 6.08s
# 8300:	learn: 0.1945023	total: 28.8s	remaining: 5.9s
# 8350:	learn: 0.1940213	total: 29s	remaining: 5.73s
# 8400:	learn: 0.1935651	total: 29.2s	remaining: 5.55s
# 8450:	learn: 0.1931217	total: 29.4s	remaining: 5.38s
# 8500:	learn: 0.1926542	total: 29.5s	remaining: 5.21s
# 8550:	learn: 0.1922167	total: 29.7s	remaining: 5.03s
# 8600:	learn: 0.1918120	total: 29.9s	remaining: 4.86s
# 8650:	learn: 0.1913698	total: 30s	remaining: 4.68s
# 8700:	learn: 0.1909786	total: 30.2s	remaining: 4.51s
# 8750:	learn: 0.1905454	total: 30.4s	remaining: 4.33s
# 8800:	learn: 0.1900711	total: 30.5s	remaining: 4.16s
# 8850:	learn: 0.1896089	total: 30.7s	remaining: 3.99s
# 8900:	learn: 0.1891849	total: 30.9s	remaining: 3.81s
# 8950:	learn: 0.1888177	total: 31s	remaining: 3.64s
# 9000:	learn: 0.1883960	total: 31.2s	remaining: 3.46s
# 9050:	learn: 0.1879859	total: 31.4s	remaining: 3.29s
# 9100:	learn: 0.1875927	total: 31.5s	remaining: 3.12s
# 9150:	learn: 0.1871980	total: 31.7s	remaining: 2.94s
# 9200:	learn: 0.1867740	total: 31.9s	remaining: 2.77s
# 9250:	learn: 0.1864406	total: 32.1s	remaining: 2.6s
# 9300:	learn: 0.1860224	total: 32.2s	remaining: 2.42s
# 9350:	learn: 0.1856607	total: 32.4s	remaining: 2.25s
# 9400:	learn: 0.1852649	total: 32.6s	remaining: 2.08s
# 9450:	learn: 0.1848677	total: 32.8s	remaining: 1.9s
# 9500:	learn: 0.1844855	total: 32.9s	remaining: 1.73s
# 9550:	learn: 0.1840885	total: 33.1s	remaining: 1.56s
# 9600:	learn: 0.1837405	total: 33.3s	remaining: 1.38s
# 9650:	learn: 0.1833244	total: 33.4s	remaining: 1.21s
# 9700:	learn: 0.1829745	total: 33.6s	remaining: 1.03s
# 9750:	learn: 0.1825758	total: 33.8s	remaining: 863ms
# 9800:	learn: 0.1822250	total: 34s	remaining: 689ms
# 9850:	learn: 0.1818553	total: 34.1s	remaining: 516ms
# 9900:	learn: 0.1814723	total: 34.3s	remaining: 343ms
# 9950:	learn: 0.1811382	total: 34.5s	remaining: 170ms
# 9999:	learn: 0.1808036	total: 34.6s	remaining: 0us

# %% [markdown]
# # Submition

# %%
# Preprocess test data
test_features = test_df.drop(columns=['id', 'date'], errors='ignore')  # Drop unnecessary columns
test_features = test_features.reindex(columns=X_train.columns, fill_value=0)  # Align columns with training data

# %%
# Predict using the trained CatBoost model
test_df['sales'] = catboost_model.predict(test_features)

# %%
# Reverse log transformation if applied during training
test_df['sales'] = np.expm1(test_df['sales'])  # Use np.expm1 if np.log1p was used during training

# Clip predictions to avoid negative values (optional)
test_df['sales'] = test_df['sales'].clip(lower=0)

# %%
# Create submission file
submission = test_df[['id', 'sales']]  # Include 'id' and the predicted target column
submission.to_csv('submission.csv', index=False)

print("Submission file created: submission.csv")
# Out:
# Submission file created: submission.csv
